-- %% [markdown]
-- Neues Schema erstellen

-- %%
%sql
CREATE SCHEMA new_default

-- %% [markdown]
-- Catalog und Schema wählen

-- %%
%sql
USE CATALOG workspace;
USE SCHEMA new_default;

-- %% [markdown]
-- Tabelle erstellen und abfüllen

-- %%
%sql
CREATE TABLE managed_default
(country STRING, code STRING, dial_code STRING) USING DELTA;


INSERT INTO managed_default
VALUES ('France', 'FR', '+33'),
('Spain',  'ES', '+34');

-- %% [markdown]
-- Metadaten explorieren

-- %%
DESCRIBE DETAIL managed_default;

-- %%
%sql
DESCRIBE EXTENDED managed_default

-- %% [markdown]
-- Tabelle abfragen

-- %%
%sql
SELECT  * FROM managed_default
