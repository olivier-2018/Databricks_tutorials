# %%
# %sql
USE CATALOG workspace;
USE SCHEMA default;

# %%
# %sql
DROP TABLE IF EXISTS default.dashboard_data;

# %%
df = spark.read.csv(
    "/Volumes/workspace/default/volume/dashboard_data.csv",
    header=True,
   
)
df.write.format("delta").saveAsTable("default.dashboard_data")

# %%
# %sql
SELECT * FROM default.dashboard_data
